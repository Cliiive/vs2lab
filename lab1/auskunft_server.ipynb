# %%
from clientserver import Server
server = Server()

print("Starting server...")
server.serve()
# Out:
# 2025-11-01 18:43:08,814 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=73, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
