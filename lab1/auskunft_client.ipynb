# %%
from clientserver import Client

cl = Client()
phone_number = cl.get( name="Anna Mueller")
print(f"Phone number for Anna Mueller: {phone_number}")

phone_book = cl.get_all()
print("Complete phone book:")
print(phone_book)
cl.close()
# Out:
# 2025-11-01 19:14:21,779 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=82, family=2, type=1, proto=0, laddr=('127.0.0.1', 48426), raddr=('127.0.0.1', 4444)>
# 2025-11-01 19:14:21,782 - vs2lab.a1_layers.clientserver.Client - INFO - Client sending GET request for name: Anna Mueller
# 2025-11-01 19:14:21,783 - vs2lab.a1_layers.clientserver.Client - INFO - Client sent GET request for name: Anna Mueller
# 2025-11-01 19:14:21,788 - vs2lab.a1_layers.clientserver.Client - INFO - Client received data: b'+49 151 2345678'
# 2025-11-01 19:14:21,790 - vs2lab.a1_layers.clientserver.Client - INFO - Client sending GETALL request
# 2025-11-01 19:14:21,792 - vs2lab.a1_layers.clientserver.Client - INFO - Client sent GETALL request
# ...
