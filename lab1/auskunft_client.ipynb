# %%
from clientserver import Client

cl = Client()
phone_number = cl.get( name="Anna Mueller")
print(f"Phone number for Anna Mueller: {phone_number}")

phone_book = cl.get_all()
print("Complete phone book:")
print(phone_book)
# Out:
# 2025-11-01 18:47:06,875 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=83, family=2, type=1, proto=0, laddr=('127.0.0.1', 45686), raddr=('127.0.0.1', 50007)>
